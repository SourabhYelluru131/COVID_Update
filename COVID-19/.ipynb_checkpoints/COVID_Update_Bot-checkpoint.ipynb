# %%
import requests,bs4,time,datetime
import re,json
def check():
    global resn
    global res
    global total_confirm_Ktk
    global total_death_Ktk
    global total_recover_Ktk
    flagc = 0
    flagd = 0
    flagf = 0
    Covidpgn = requests.get("https://api.covid19india.org/data.json",)
    cpsn = bs4.BeautifulSoup(Covidpgn.content)
    drn = cpsn.find('p')
    datan = []
    for label in drn:
        keyn = re.sub(r'\s+', ' ', str(label).strip())
        valuen = str(label.find_next_sibling()).strip()
        datan.append({ keyn : valuen })
    resn = json.loads(list(datan[0].keys())[0])
    retlist = []
    if resn['statewise'][0]['confirmed'] != res['statewise'][0]['confirmed']:
        flagc = 1
        diff = int(resn['statewise'][0]['confirmed'])-int(res['statewise'][0]['confirmed'])
        retlist.append({"India new confirms":diff})
    if resn['statewise'][0]['deaths'] != res['statewise'][0]['deaths']:
        flagd = 1
        diff = int(resn['statewise'][0]['deaths'])-int(res['statewise'][0]['deaths'])
        retlist.append({"India new deaths":diff})
    if resn['statewise'][0]['recovered'] != res['statewise'][0]['recovered']:
        flagf = 1
        diff = int(resn['statewise'][0]['recovered'])-int(res['statewise'][0]['recovered'])
        retlist.append({"India new recoveries":diff})
    if flagc or flagd or flagf:
        listofresn = []
        for a in resn['statewise']:
            listofresn.append(a)
        for a in listofresn:
            if a['state']=="Karnataka":
                tindn = listofresn.index(a)
                break
        ktkdictn = resn['statewise'][tindn]
        if flagc:
            if ktkdictn['confirmed'] != total_confirm_Ktk:
                diffs = int(ktkdictn['confirmed'])-total_confirm_Ktk
                retlist.append({"Karnataka new confirms":diffs})
        if flagd:
            if ktkdictn['deaths'] != total_death_Ktk:
                diffs = int(ktkdictn['deaths'])-total_death_Ktk
                retlist.append({"Karnataka new deaths":diffs})
        if flagc:
            if ktkdictn['recovered'] != total_recover_Ktk:
                diffs = int(ktkdictn['recovered'])-total_recover_Ktk
                retlist.append({"Karnataka new recoveries":diffs})
    if retlist:
        return retlist
    else:
        return None
def get_results():
    global res
    global total_confirm_India
    global total_death_India
    global total_recover_India
    global confirm_since_yesterday_India
    global death_since_yesterday_India
    global recover_since_yesterday_India
    global Highest_state_India
    global confirm_in_highest_state
    global death_in_highest_state
    global recover_in_highest_state
    global total_confirm_Ktk
    global total_death_Ktk
    global total_recover_Ktk
    global confirm_since_yesterday_Ktk
    global death_since_yesterday_Ktk
    global recover_since_yesterday_Ktk
    Covidpg = requests.get("https://api.covid19india.org/data.json",)
    cps = bs4.BeautifulSoup(Covidpg.content)
    dr = cps.find('p')
    data = []
    for label in dr:
        key = re.sub(r'\s+', ' ', str(label).strip())
        value = str(label.find_next_sibling()).strip()
        data.append({ key: value })
    res = json.loads(list(data[0].keys())[0]) 
    total_confirm_India = int(res['statewise'][0]['confirmed'])
    total_death_India = int(res['statewise'][0]['deaths'])
    total_recover_India = int(res['statewise'][0]['recovered'])
    confirm_since_yesterday_India = int(res['statewise'][0]['delta']['confirmed'])
    death_since_yesterday_India = int(res['statewise'][0]['delta']['deaths'])
    recover_since_yesterday_India = int(res['statewise'][0]['delta']['recovered'])
    Highest_state_India = res['statewise'][1]['state']
    confirm_in_highest_state = res['statewise'][1]['confirmed']
    death_in_highest_state = res['statewise'][1]['deaths']
    recover_in_highest_state = res['statewise'][1]['recovered']
    listofres = []
    for a in res['statewise']:
        listofres.append(a)
    for a in listofres:
        if a['state']=="Karnataka":
            tind = listofres.index(a)
            break
    ktkdict = res['statewise'][tind]
    total_confirm_Ktk = int(ktkdict['confirmed'])
    total_death_Ktk = int(ktkdict['deaths'])
    total_recover_Ktk = int(ktkdict['recovered'])
    confirm_since_yesterday_Ktk = int(ktkdict['delta']['confirmed'])
    death_since_yesterday_Ktk = int(ktkdict['delta']['deaths'])
    recover_since_yesterday_Ktk = int(ktkdict['delta']['recovered'])
def print_info():
    global total_confirm_India
    global total_death_India
    global total_recover_India
    global confirm_since_yesterday_India
    global death_since_yesterday_India
    global recover_since_yesterday_India
    global Highest_state_India
    global confirm_in_highest_state
    global death_in_highest_state
    global recover_in_highest_state
    global total_confirm_Ktk
    global total_death_Ktk
    global total_recover_Ktk
    global confirm_since_yesterday_Ktk
    global death_since_yesterday_Ktk
    global recover_since_yesterday_Ktk
    print("------------------------------")
    print("India")
    print("------------------------------")
    print("Confirm:",total_confirm_India)
    print("Dead:",total_death_India)
    print("Recovered",total_recover_India)
    print("Confirm today:",confirm_since_yesterday_India)
    print("Deaths today:",death_since_yesterday_India)
    print("Recovered today:",recover_since_yesterday_India)
    print("------------------------------")
    print(Highest_state_India)
    print("------------------------------")
    print("Confirmed:",confirm_in_highest_state)
    print("Deaths:",death_in_highest_state)
    print("Recovered:",recover_in_highest_state)
    print("------------------------------")
    print("Karnataka")
    print("------------------------------")
    print("Confirmed:",total_confirm_Ktk)
    print("Deaths:",total_death_Ktk)
    print("Recovered:",total_recover_Ktk)
    print("Confirm since today:",confirm_since_yesterday_Ktk)
    print("Deaths today:",death_since_yesterday_Ktk)
    print("------------------------------")
def print_if_changed():
    x = check()
    if x:
        for a in x:
            print("Changes : ")
            print(a)
            get_results()
            print("New Stats - ")
            get_results()
            print_info()
    else:
        print("No changes", "time :", datetime.datetime.now())
def main():
    get_results()
    print_info()
    while True:
        time.sleep(10)
        print_if_changed()
main()
# Out:
# ------------------------------
# India
# ------------------------------
# Confirm: 953
# Dead: 21
# Recovered 84
# Confirm today: 67
# Deaths today: 0
# Recovered today: 0
# ------------------------------
# Kerala
# ------------------------------
# Confirmed: 182
# Deaths: 1
# Recovered: 12
# ------------------------------
# Karnataka
# ------------------------------
# Confirmed: 74
# Deaths: 3
# Recovered: 5
# Confirm since today: 10
# Deaths today: 0
# ------------------------------
# No changes time : 2020-03-28 19:21:55.807780
# No changes time : 2020-03-28 19:22:06.129953
# No changes time : 2020-03-28 19:22:16.489362
# No changes time : 2020-03-28 19:22:26.810899
# No changes time : 2020-03-28 19:22:37.118672
# No changes time : 2020-03-28 19:22:47.401946
# No changes time : 2020-03-28 19:22:57.761398
# No changes time : 2020-03-28 19:23:08.056662
# No changes time : 2020-03-28 19:23:18.356790
# No changes time : 2020-03-28 19:23:28.676638
# No changes time : 2020-03-28 19:23:39.015497
# No changes time : 2020-03-28 19:23:49.415499
# No changes time : 2020-03-28 19:23:59.756633
# No changes time : 2020-03-28 19:24:10.092978
# No changes time : 2020-03-28 19:24:20.409643
# No changes time : 2020-03-28 19:24:30.729366
# No changes time : 2020-03-28 19:24:41.033566
# No changes time : 2020-03-28 19:24:51.369069
# No changes time : 2020-03-28 19:25:01.698105
# No changes time : 2020-03-28 19:25:12.046536
# No changes time : 2020-03-28 19:25:22.356762
# No changes time : 2020-03-28 19:25:32.685261
# No changes time : 2020-03-28 19:25:43.036738
# No changes time : 2020-03-28 19:25:53.355388
# No changes time : 2020-03-28 19:26:03.693161
# No changes time : 2020-03-28 19:26:13.997770
# No changes time : 2020-03-28 19:26:24.517559
# No changes time : 2020-03-28 19:26:34.859569
# No changes time : 2020-03-28 19:26:45.175108
# No changes time : 2020-03-28 19:26:55.516873
# No changes time : 2020-03-28 19:27:05.849669
# No changes time : 2020-03-28 19:27:16.196608
# No changes time : 2020-03-28 19:27:26.499686
# No changes time : 2020-03-28 19:27:36.870610
# No changes time : 2020-03-28 19:27:47.247373
# No changes time : 2020-03-28 19:27:57.608878
# No changes time : 2020-03-28 19:28:07.932713
# No changes time : 2020-03-28 19:28:18.275517
# No changes time : 2020-03-28 19:28:28.689099
# No changes time : 2020-03-28 19:28:39.033146
# No changes time : 2020-03-28 19:28:49.416063
# No changes time : 2020-03-28 19:28:59.859194
# No changes time : 2020-03-28 19:29:10.172350
# No changes time : 2020-03-28 19:29:20.476093
# No changes time : 2020-03-28 19:29:30.798936
# No changes time : 2020-03-28 19:29:41.117904
# No changes time : 2020-03-28 19:29:51.396499
# No changes time : 2020-03-28 19:30:01.729848
# No changes time : 2020-03-28 19:30:12.015985
# No changes time : 2020-03-28 19:30:22.334776
# No changes time : 2020-03-28 19:30:32.656524
# No changes time : 2020-03-28 19:30:43.335643
# No changes time : 2020-03-28 19:30:53.645628
# No changes time : 2020-03-28 19:31:03.957323
# No changes time : 2020-03-28 19:31:14.447154
# No changes time : 2020-03-28 19:31:24.762471
# No changes time : 2020-03-28 19:31:35.130168
# No changes time : 2020-03-28 19:31:45.435489
# No changes time : 2020-03-28 19:31:55.752218
# No changes time : 2020-03-28 19:32:06.058774
# No changes time : 2020-03-28 19:32:16.355438
# No changes time : 2020-03-28 19:32:26.658274
# No changes time : 2020-03-28 19:32:36.959199
# No changes time : 2020-03-28 19:32:47.366994
# No changes time : 2020-03-28 19:32:57.677075
# No changes time : 2020-03-28 19:33:08.019409
# No changes time : 2020-03-28 19:33:18.298045
# No changes time : 2020-03-28 19:33:28.686288
# No changes time : 2020-03-28 19:33:38.996732
# No changes time : 2020-03-28 19:33:49.556055
# No changes time : 2020-03-28 19:33:59.857072
# No changes time : 2020-03-28 19:34:10.176012
# No changes time : 2020-03-28 19:34:20.486359
# No changes time : 2020-03-28 19:34:31.090250
# No changes time : 2020-03-28 19:34:41.376295
# No changes time : 2020-03-28 19:34:51.717848
# No changes time : 2020-03-28 19:35:02.041915
# No changes time : 2020-03-28 19:35:12.357621
# No changes time : 2020-03-28 19:35:24.175741
# No changes time : 2020-03-28 19:35:34.518041
# No changes time : 2020-03-28 19:35:44.807346
# No changes time : 2020-03-28 19:35:55.111712
# No changes time : 2020-03-28 19:36:05.408484
# No changes time : 2020-03-28 19:36:15.695759
# No changes time : 2020-03-28 19:36:26.015976
# No changes time : 2020-03-28 19:36:37.365632
# No changes time : 2020-03-28 19:36:47.736685
# No changes time : 2020-03-28 19:36:58.077642
# No changes time : 2020-03-28 19:37:08.396096
# No changes time : 2020-03-28 19:37:18.717542
# No changes time : 2020-03-28 19:37:29.037963
# No changes time : 2020-03-28 19:37:39.536985
# No changes time : 2020-03-28 19:37:49.857271
# No changes time : 2020-03-28 19:38:00.576752
# No changes time : 2020-03-28 19:38:10.892050
# No changes time : 2020-03-28 19:38:21.556680
# No changes time : 2020-03-28 19:38:31.872601
# No changes time : 2020-03-28 19:38:42.193053
# No changes time : 2020-03-28 19:38:52.477366
# No changes time : 2020-03-28 19:39:02.812400
# No changes time : 2020-03-28 19:39:13.113316
# No changes time : 2020-03-28 19:39:23.437144
# No changes time : 2020-03-28 19:39:33.731172
# No changes time : 2020-03-28 19:39:44.053300
# No changes time : 2020-03-28 19:39:54.477135
# No changes time : 2020-03-28 19:40:04.776304
# No changes time : 2020-03-28 19:40:15.138156
# No changes time : 2020-03-28 19:40:25.456332
# No changes time : 2020-03-28 19:40:35.758689
# No changes time : 2020-03-28 19:40:46.061778
# No changes time : 2020-03-28 19:40:56.362213
# No changes time : 2020-03-28 19:41:06.658478
# No changes time : 2020-03-28 19:41:16.976407
# No changes time : 2020-03-28 19:41:27.332841
# No changes time : 2020-03-28 19:41:37.637429
# No changes time : 2020-03-28 19:41:47.976542
# No changes time : 2020-03-28 19:41:58.296394
# No changes time : 2020-03-28 19:42:08.652591
# No changes time : 2020-03-28 19:42:18.966837
# No changes time : 2020-03-28 19:42:29.377328
# No changes time : 2020-03-28 19:42:39.717217
# No changes time : 2020-03-28 19:42:50.037774
# Changes :
# {'India new confirms': 6}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4c4ef1e7acf1> in <module>
#     167         time.sleep(10)
#     168         print_if_changed()
# --> 169 main()
#
# <ipython-input-5-4c4ef1e7acf1> in main()
#     166     while True:
#     167         time.sleep(10)
# --> 168         print_if_changed()
#     169 main()
#
# <ipython-input-5-4c4ef1e7acf1> in print_if_changed()
#     155             print("Changes : ")
#     156             print(a)
# --> 157             get_resuls()
#     158             print("New Stats - ")
#     159             get_results()
#
# NameError: name 'get_resuls' is not defined
